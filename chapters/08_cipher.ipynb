# %% [markdown]
# [矢吹太朗『Webのしくみ』（サイエンス社, 2020）](https://github.com/taroyabuki/webbook)
#
# 下のアイコンをクリックすれば，この文書に掲載されているコードを，Google Colab上で実行できます．（Googleのアカウントが必要です．）
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/taroyabuki/webbook/blob/master/chapters/08_cipher.ipynb)
#
# # 第8章 暗号

# %% [markdown]
# ## 8.1 事後否認・改ざん・なりすまし・盗聴

# %% [markdown]
# ## 8.2 暗号の基本
#
# ![図8.1 シーザー暗号（「+13」文字ずらす）を使って，アリスがボブにメッセージを送っている様子](https://raw.githubusercontent.com/taroyabuki/webbook/master/chapters/figures/08-1.svg)

# %%
#準備
# !apt-get install -y -qq hxtools > /dev/null

# %%
#暗号化
# !echo "hello" | rot13
# Out:
# uryyb

# %%
#復号
# !echo "hello" | rot13 | rot13

# %% [markdown]
# ## 8.3 公開鍵暗号

# %% [markdown]
# ### 8.3.1 盗聴への対策
#
# アリスはボブの公開鍵で暗号化し，ボブはボブの秘密鍵で復号します．
#
# ![図8.2 公開鍵暗号を使った暗号化と復号](https://raw.githubusercontent.com/taroyabuki/webbook/master/chapters/figures/08-2.svg)
#
# ファイル|役割
# --|--
# bob-public.pem|ボブの公開鍵
# bob-private.pem|ボブの秘密鍵
# message4bob|ボブへのメッセージ
# message4bob-secret|ボブへの暗号文

# %%
#(1) ボブが公開鍵と秘密鍵を作る．
# !openssl genrsa -out bob-private.pem 2048
# !openssl rsa -in bob-private.pem -pubout -out bob-public.pem
# Out:
# writing RSA key

# %%
#公開鍵を見てみる．
# !cat bob-public.pem
# Out:
# -----BEGIN PUBLIC KEY-----
# MIIBIjANBgkqhkiG9w0BAQEFAAOCAQ8AMIIBCgKCAQEAvp8J7RfMTavSwG7/ACok
# ATNB4Ljq8G7Km0Jtk66Oi3MBagHT0NEEC4vIzm00lqdk1yABScC35PZ62qsFmygH
# zbTB6bsJa48AlGpxE6Ww9rjJMGGnrWkyxXcjQUF5HGB2OVt6oDg9jRcELNmJvqC4
# +fkF8TG12c+LURdeJ7IVGCnDAHcSzO7TfBNYA+mAvd1sv2Qyq5ZoUtjzuNQAA0uJ
# qAW2OBFTy18PcF+8EV5QPGqoNOAFWX6MPf6jhXD0iUG7Tpl4WDQyGlRZRZd/fL4n
# clAJAzokAx5S7RVzP9Otnz9S5bNim9uTS42/HNxATctDWyr3p5rfHMOndMNZM4cX
# twIDAQAB
# -----END PUBLIC KEY-----

# %%
#秘密鍵を見てみる（秘密鍵は本来見せたり公開したりしてはいけない）．
# !cat bob-private.pem
# Out:
# -----BEGIN PRIVATE KEY-----
# MIIEvAIBADANBgkqhkiG9w0BAQEFAASCBKYwggSiAgEAAoIBAQC+nwntF8xNq9LA
# bv8AKiQBM0HguOrwbsqbQm2Tro6LcwFqAdPQ0QQLi8jObTSWp2TXIAFJwLfk9nra
# xFIvlcNGyeh88dPOQDAs4Q==
# -----END PRIVATE KEY-----

# %%
#(2) ボブが公開鍵を公開する．

#(3) アリスがボブの公開鍵を手に入れる．

#(4) アリスがボブの公開鍵を使ってメッセージを暗号化し，ボブに送る．

#(4.1) メッセージをファイルに書く．
# !printf "26G3027\n" > message4bob

#(4.2) ボブの公開鍵を使って暗号文を作る．
# !openssl pkeyutl -encrypt -pubin -inkey bob-public.pem -in message4bob -out message4bob-secret
# !base64 message4bob-secret
# Out:
# sgpuRs6k52Ysl+rMHZMpN/b2Zi3CQX9z3KG4uv69DUbMIrwKXjyMr2OgAq45QPVye6ejHbSuO9+X
# IZhu3bluQDY5sDpRN6tOGiMgpGwlAXgDJi2uHAFxDon7lEhenf7H9U79ssraSDwszJJ+2Sp01PhB
# 7i62ZD7VCKOu+YKUzy4S1btfUOaliO4J/UnW1pGZgHIi/DNo4S8XOT9xyfeUcPupgyBnJUvE5aXT
# H7AzRJf/OyOUZzJtk/Eo/wxefSp158mVkVOerb0JpjqHX4h+P9P/JYCQApACtYDvDgB5ObkAqmJ/
# As7e/M6F0gb9Gn4ABpBzTmRQuEoZIhECa6q1uw==

# %%
#(5) ボブが暗号文を受け取り，秘密鍵を使って復号する．
# !openssl pkeyutl -decrypt -inkey bob-private.pem -in message4bob-secret
# Out:
# 26G3027

# %% [markdown]
# ### 8.3.2 デジタル署名
#
# アリスはアリスの秘密鍵でデジタル署名を作り，ボブはアリスの公開鍵でデジタル署名を検証します．
#
# ファイル|役割
# --|--
# alice-public.pem|アリスの公開鍵
# alice-private.pem|アリスの秘密鍵
# alice-message|アリスのメッセージ
# alice-message-signature|アリスのデジタル署名

# %% [markdown]
# #### デジタル署名

# %%
#(1) アリスが公開鍵と秘密鍵を作る．
# !openssl genrsa -out alice-private.pem 2048
# !openssl rsa -in alice-private.pem -pubout -out alice-public.pem

# %%
#(2) アリスがメッセージをファイルに書き，アリスが秘密鍵を使ってデジタル署名を作る．
# !printf "HELLO\n" > alice-message
# !openssl dgst -sha256 -sign alice-private.pem -out alice-message-signature alice-message

# %%
#(3) アリスが公開鍵を公開する．

#(4) ボブがアリスの公開鍵，メッセージ，デジタル署名を取得する．

#(5) ボブがアリスの公開鍵を使って，メッセージのデジタル署名を検証する．
# !openssl dgst -sha256 -verify alice-public.pem -signature alice-message-signature alice-message
# Out:
# Could not open file or uri for loading public key from alice-public.pem
# 40372787407A0000:error:16000069:STORE routines:ossl_store_get0_loader_int:unregistered scheme:../crypto/store/store_register.c:237:scheme=file
# 40372787407A0000:error:80000002:system library:file_open:No such file or directory:../providers/implementations/storemgmt/file_store.c:267:calling stat(alice-public.pem)

# %% [markdown]
# ### 8.3.3 デジタル証明書

# %% [markdown]
# ## 8.4 ウェブの安全性

# %% [markdown]
# ### 8.4.1 TLS
